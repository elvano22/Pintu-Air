# %%
# ONLY RUN THIS IF YOU'RE IN GOOGLE COLAB
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Thesis/Pintu-Air/notebooks')

# Verify you're in the right place
# !pwd
# !ls -la
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Thesis/Pintu-Air/notebooks
# total 23638
# -rw------- 1 root root 5517847 Jun 19 04:28 '01 Result Data Cleaning Part 1.csv'
# -rw------- 1 root root 2009870 Jun 19 04:28 '02 All Data.csv'
# -rw------- 1 root root 1591313 Jun 19 04:28 '02 Data Preperation.ipynb'
# -rw------- 1 root root  256098 Jun 19 04:28 '02 X_test.csv'
# -rw------- 1 root root 4831129 Jun 19 04:28 '02 X_train.csv'
# -rw------- 1 root root   40580 Jun 19 04:28 '02 y_test.csv'
# -rw------- 1 root root  770651 Jun 19 04:28 '02 y_train.csv'
# -rw------- 1 root root 1657773 Jun 19 04:28  03_ARIMA.ipynb
# -rw------- 1 root root    2708 Jun 19 04:28  03_arima_results_all_significant.csv
# -rw------- 1 root root   49684 Jun 19 04:28  03_arima_results.csv
# -rw------- 1 root root 1737590 Jun 19 04:28  04_XGBoost.ipynb
# -rw------- 1 root root  950934 Jun 19 04:29 '04_XGBoost Reduced.ipynb'
# -rw------- 1 root root 1844123 Jun 19 04:28  05_SARIMAX.ipynb
# -rw------- 1 root root   87178 Jun 19 07:56  06b_LSTM_with_lag.ipynb
# -rw------- 1 root root  631461 Jun 19 04:28  06_DataPreperation_ML.ipynb
# -rw------- 1 root root  117772 Jun 19 07:56  06_LSTM.ipynb
# -rw------- 1 root root  395764 Jun 19 04:28  07a_LSTM_Manggarai.ipynb
# -rw------- 1 root root  370151 Jun 19 04:28  07b_LSTM_Manggarai_with_weather.ipynb
# -rw------- 1 root root  122861 Jun 19 04:28 '08 grid3_search_results.csv'
# -rw------- 1 root root  216802 Jun 19 04:28 '08 grid_search2_reduced_results.csv'
# -rw------- 1 root root   91708 Jun 19 04:28 '08 grid_search_2_results.csv'
# -rw------- 1 root root  215895 Jun 19 04:28 '08 grid_search_reduced_results.csv'
# -rw------- 1 root root  217793 Jun 19 04:28 '08 grid_search_results.csv'
# -rw------- 1 root root  464680 Jun 19 05:53  best_lstm_model.h5
# -rw------- 1 root root    1725 Jun 19 07:30  lstm2_grid_search_results.csv
# drwx------ 2 root root    4096 Jun 19 05:24 'saved plots'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

from itertools import product
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# GPU Configuration
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# ADD THIS BLOCK:
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled")
    except RuntimeError as e:
        print(f"GPU setup error: {e}")
# Out:
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU memory growth enabled

# %%
# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
y_train = (pd.read_csv("02 y_train.csv", index_col='Tanggal')).values
y_test = (pd.read_csv("02 y_test.csv", index_col='Tanggal')).values

# %%
all_df = pd.read_csv("02 All Data.csv")
all_df['Tanggal'] = pd.to_datetime(all_df['Tanggal'])

# Create new dataframe for lagged features
X = pd.DataFrame(index=all_df.index)

# Target variable (current Manggarai and 1 hour back)
X['Manggarai'] = all_df['Manggarai (air)']

# Cross-correlation lags for Depok (8 hours back)
X['Depok Lag 8'] = all_df['Depok (air)'].shift(8)

# Cross-correlation lags for Katulampa (11 hours back)
X['Katulampa Lag 11'] = all_df['Katulampa (air)'].shift(11)

X = X.iloc[24:]
del all_df

# %%
# Train-Test Split
split_idx = int(len(X) * 0.95)
X_train, X_test = X[:split_idx], X[split_idx:]

# Scaling
# scaler_X = MinMaxScaler()
# scaler_y = MinMaxScaler()
scaler_X = RobustScaler()
scaler_y = RobustScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()


print(f"\n{'='*60}\nData Train and Test Distribution:\n{'='*60}")

print(f'Jumlah data: {len(X)}')

print(f'Jumlah data X train: {len(X_train)}')
print(f'Jumlah data X test: {len(X_test)}')

print(f'Jumlah data y train: {len(y_train)}')
print(f'Jumlah data y test: {len(y_test)}')
# Out:
# ============================================================
# Data Train and Test Distribution:
# ============================================================
# Jumlah data: 31200
# Jumlah data X train: 29640
# Jumlah data X test: 1560
# Jumlah data y train: 29640
# Jumlah data y test: 1560

# %%
def create_sequences(X, y, seq_len):
    X_seq, y_seq = [], []

    for i in range(seq_len, len(X)):
        # Take seq_len previous time steps as features
        X_seq.append(X[i-seq_len:i])
        # Current time step as target
        y_seq.append(y[i])

    return np.array(X_seq), np.array(y_seq)

# %%
def build_model(seq_len, n_features, units, dropout, lr):
    """Build LSTM model"""
    model = Sequential()

    for i, unit in enumerate(units):
        return_seq = i < len(units) - 1
        if i == 0:
            model.add(LSTM(unit, return_sequences=return_seq, input_shape=(seq_len, n_features)))
        else:
            model.add(LSTM(unit, return_sequences=return_seq))
        model.add(Dropout(dropout))

    model.add(Dense(16, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=lr), loss='mse', metrics=['mae'])
    return model

# %%
def evaluate_model(model, X_seq, y_true, scaler_y):
    """Evaluate model performance"""
    y_pred_scaled = model.predict(X_seq, verbose=0)
    y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    return {
        'rmse': np.sqrt(mean_squared_error(y_true, y_pred)),
        'mae': mean_absolute_error(y_true, y_pred),
        'r2': r2_score(y_true, y_pred),
        'mape': mean_absolute_percentage_error(y_true, y_pred) * 100
    }

# %%
def save_learning_curves(history, combo_id, params):
    """Save learning curves"""
    os.makedirs('saved plots', exist_ok=True)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    ax1.plot(history.history['loss'], label='Train')
    ax1.plot(history.history['val_loss'], label='Validation')
    ax1.set_title(f'Loss - Combo {combo_id}')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True)

    ax2.plot(history.history['mae'], label='Train')
    ax2.plot(history.history['val_mae'], label='Validation')
    ax2.set_title(f'MAE - Combo {combo_id}')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('MAE')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()

    filename = f"brobust_combo_{combo_id}_lr{params['learning_rate']}_drop{params['dropout_rate']}.png"
    plt.savefig(f"saved plots/{filename}", dpi=100, bbox_inches='tight')
    plt.close()

# %%
def lstm_grid_search(X_train, y_train_scaled, X_test, y_test, scaler_y, param_grid):
    """
    Perform LSTM grid search with comprehensive evaluation
    """
    param_combinations = list(product(*param_grid.values()))
    param_names = list(param_grid.keys())
    total_combinations = len(param_combinations)

    print(f"Starting grid search: {total_combinations} combinations")

    results = []
    best_score = float('inf')
    best_params = None

    for i, params in enumerate(param_combinations):
        param_dict = dict(zip(param_names, params))
        print(f"\nCombination {i+1}/{total_combinations}: {param_dict}")
        print(f"Progress: {(i+1)/total_combinations*100:.1f}%")

        try:
            # Create sequences
            X_seq, y_seq = create_sequences(X_train, y_train_scaled, param_dict['sequence_length'])

            # Train-validation split
            val_size = int(len(X_seq) * 0.2)
            X_train_fold = X_seq[:-val_size]
            y_train_fold = y_seq[:-val_size]
            X_val_fold = X_seq[-val_size:]
            y_val_fold = y_seq[-val_size:]

            # Build and train model
            model = build_model(
                param_dict['sequence_length'],
                X_seq.shape[2],
                param_dict['lstm_units'],
                param_dict['dropout_rate'],
                param_dict['learning_rate']
            )

            callbacks = [
                EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=0),
                ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=0.00001, verbose=0)
            ]

            history = model.fit(
                X_train_fold, y_train_fold,
                epochs=param_dict['epochs'],
                batch_size=param_dict['batch_size'],
                validation_data=(X_val_fold, y_val_fold),
                callbacks=callbacks,
                verbose=1
            )

            # Save learning curves
            save_learning_curves(history, i+1, param_dict)

            # Evaluate on all sets (convert scaled targets back to original scale)
            y_train_fold_orig = scaler_y.inverse_transform(y_train_fold.reshape(-1, 1)).flatten()
            y_val_fold_orig = scaler_y.inverse_transform(y_val_fold.reshape(-1, 1)).flatten()

            train_metrics = evaluate_model(model, X_train_fold, y_train_fold_orig, scaler_y)
            val_metrics = evaluate_model(model, X_val_fold, y_val_fold_orig, scaler_y)

            # Test evaluation
            X_test_seq, _ = create_sequences(X_test, y_test.flatten(), param_dict['sequence_length'])
            y_test_actual = y_test[param_dict['sequence_length']:]
            test_metrics = evaluate_model(model, X_test_seq, y_test_actual, scaler_y)

            # Store results (including essential history)
            result = {
                **param_dict,
                'train_rmse': train_metrics['rmse'],
                'train_r2': train_metrics['r2'],
                'val_rmse': val_metrics['rmse'],
                'val_r2': val_metrics['r2'],
                'test_rmse': test_metrics['rmse'],
                'test_r2': test_metrics['r2'],
                'test_mae': test_metrics['mae'],
                'test_mape': test_metrics['mape'],
                'epochs_trained': len(history.history['loss']),
                'final_train_loss': history.history['loss'][-1],
                'final_val_loss': history.history['val_loss'][-1],
                'best_val_loss': min(history.history['val_loss'])
            }
            results.append(result)

            print(f"Results - Train RMSE: {train_metrics['rmse']:.4f}, Test RMSE: {test_metrics['rmse']:.4f}, R2: {test_metrics['r2']:.4f}")

            if test_metrics['rmse'] < best_score:
                best_score = test_metrics['rmse']
                best_params = param_dict.copy()
                print(f"New best model found!")

        except Exception as e:
            print(f"Error in combination {i+1}: {str(e)}")
            results.append({**param_dict, 'error': str(e), 'test_rmse': float('inf')})

    return results, best_params, best_score

# %%
# Parameter Grid
param_grid = {
    'sequence_length': [24],
    'lstm_units': [[32], [64]],
    'dropout_rate': [0.3, 0.5],
    'learning_rate': [0.001],
    'batch_size': [64],
    'epochs': [30]
}

# %%
# Run Grid Search
results, best_params, best_score = lstm_grid_search(X_train, y_train_scaled, X_test, y_test, scaler_y, param_grid)

print(f"\nGrid search completed. Best RMSE: {best_score:.4f}")
print(f"Best parameters: {best_params}")
# Out:
# Starting grid search: 4 combinations
#
# Combination 1/4: {'sequence_length': 24, 'lstm_units': [32], 'dropout_rate': 0.3, 'learning_rate': 0.001, 'batch_size': 64, 'epochs': 30}
# Progress: 25.0%
# Epoch 1/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6805 - mae: 0.6245 - val_loss: 0.3381 - val_mae: 0.3004 - learning_rate: 0.0010
# Epoch 2/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4618 - mae: 0.4926 - val_loss: 0.3318 - val_mae: 0.3043 - learning_rate: 0.0010
# Epoch 3/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4503 - mae: 0.4828 - val_loss: 0.3300 - val_mae: 0.2982 - learning_rate: 0.0010
# Epoch 4/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.4486 - mae: 0.4803 - val_loss: 0.3322 - val_mae: 0.3003 - learning_rate: 0.0010
# Epoch 5/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.4459 - mae: 0.4786 - val_loss: 0.3205 - val_mae: 0.2923 - learning_rate: 0.0010
# Epoch 6/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4474 - mae: 0.4808 - val_loss: 0.3348 - val_mae: 0.3034 - learning_rate: 0.0010
# Epoch 7/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4418 - mae: 0.4779 - val_loss: 0.3163 - val_mae: 0.2825 - learning_rate: 0.0010
# Epoch 8/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.4179 - mae: 0.4592 - val_loss: 0.3152 - val_mae: 0.2896 - learning_rate: 0.0010
# Epoch 9/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.4185 - mae: 0.4588 - val_loss: 0.3406 - val_mae: 0.3165 - learning_rate: 0.0010
# Epoch 10/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4107 - mae: 0.4508 - val_loss: 0.3054 - val_mae: 0.2885 - learning_rate: 0.0010
# Epoch 11/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4064 - mae: 0.4539 - val_loss: 0.3341 - val_mae: 0.3124 - learning_rate: 0.0010
# Epoch 12/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4032 - mae: 0.4432 - val_loss: 0.3275 - val_mae: 0.3116 - learning_rate: 0.0010
# Epoch 13/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.3979 - mae: 0.4462 - val_loss: 0.3306 - val_mae: 0.3098 - learning_rate: 0.0010
# Epoch 14/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3905 - mae: 0.4392 - val_loss: 0.3311 - val_mae: 0.3182 - learning_rate: 0.0010
# Epoch 15/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3852 - mae: 0.4345 - val_loss: 0.3470 - val_mae: 0.3361 - learning_rate: 0.0010
# Epoch 16/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3905 - mae: 0.4398 - val_loss: 0.3270 - val_mae: 0.3165 - learning_rate: 0.0010
# Epoch 17/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.3761 - mae: 0.4303 - val_loss: 0.3338 - val_mae: 0.3330 - learning_rate: 0.0010
# Epoch 18/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3626 - mae: 0.4190 - val_loss: 0.3253 - val_mae: 0.3210 - learning_rate: 0.0010
# Epoch 19/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3523 - mae: 0.4082 - val_loss: 0.2834 - val_mae: 0.2668 - learning_rate: 5.0000e-04
# Epoch 20/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3363 - mae: 0.3968 - val_loss: 0.2934 - val_mae: 0.2943 - learning_rate: 5.0000e-04
# Epoch 21/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3272 - mae: 0.3919 - val_loss: 0.2944 - val_mae: 0.3026 - learning_rate: 5.0000e-04
# Epoch 22/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.3167 - mae: 0.3846 - val_loss: 0.2817 - val_mae: 0.2775 - learning_rate: 5.0000e-04
# Epoch 23/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.3088 - mae: 0.3793 - val_loss: 0.2745 - val_mae: 0.2679 - learning_rate: 5.0000e-04
# Epoch 24/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2979 - mae: 0.3705 - val_loss: 0.2585 - val_mae: 0.2431 - learning_rate: 5.0000e-04
# Epoch 25/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2755 - mae: 0.3540 - val_loss: 0.2532 - val_mae: 0.2455 - learning_rate: 5.0000e-04
# Epoch 26/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2596 - mae: 0.3350 - val_loss: 0.2538 - val_mae: 0.2465 - learning_rate: 5.0000e-04
# Epoch 27/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.2387 - mae: 0.3164 - val_loss: 0.2225 - val_mae: 0.1727 - learning_rate: 5.0000e-04
# Epoch 28/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.2195 - mae: 0.2981 - val_loss: 0.2179 - val_mae: 0.1667 - learning_rate: 5.0000e-04
# Epoch 29/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2029 - mae: 0.2795 - val_loss: 0.2123 - val_mae: 0.1550 - learning_rate: 5.0000e-04
# Epoch 30/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1914 - mae: 0.2662 - val_loss: 0.2266 - val_mae: 0.1925 - learning_rate: 5.0000e-04
# Results - Train RMSE: 22.8118, Test RMSE: 25.7432, R2: 0.1595
# New best model found!
#
# Combination 2/4: {'sequence_length': 24, 'lstm_units': [32], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'batch_size': 64, 'epochs': 30}
# Progress: 50.0%
# Epoch 1/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.7192 - mae: 0.6562 - val_loss: 0.3691 - val_mae: 0.3684 - learning_rate: 0.0010
# Epoch 2/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.5275 - mae: 0.5445 - val_loss: 0.3484 - val_mae: 0.3378 - learning_rate: 0.0010
# Epoch 3/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.5012 - mae: 0.5229 - val_loss: 0.3680 - val_mae: 0.3558 - learning_rate: 0.0010
# Epoch 4/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.4814 - mae: 0.5090 - val_loss: 0.3727 - val_mae: 0.3489 - learning_rate: 0.0010
# Epoch 5/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.4757 - mae: 0.5050 - val_loss: 0.3728 - val_mae: 0.3399 - learning_rate: 0.0010
# Epoch 6/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4708 - mae: 0.5004 - val_loss: 0.3676 - val_mae: 0.3283 - learning_rate: 0.0010
# Epoch 7/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4753 - mae: 0.5016 - val_loss: 0.3571 - val_mae: 0.3166 - learning_rate: 0.0010
# Epoch 8/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.4619 - mae: 0.4952 - val_loss: 0.4054 - val_mae: 0.3677 - learning_rate: 0.0010
# Epoch 9/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4588 - mae: 0.4906 - val_loss: 0.3771 - val_mae: 0.3292 - learning_rate: 0.0010
# Epoch 10/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.4427 - mae: 0.4778 - val_loss: 0.4081 - val_mae: 0.3595 - learning_rate: 0.0010
# Epoch 11/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.4182 - mae: 0.4636 - val_loss: 0.4132 - val_mae: 0.3709 - learning_rate: 5.0000e-04
# Epoch 12/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.4130 - mae: 0.4583 - val_loss: 0.4073 - val_mae: 0.3554 - learning_rate: 5.0000e-04
# Epoch 13/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.4108 - mae: 0.4528 - val_loss: 0.4256 - val_mae: 0.3737 - learning_rate: 5.0000e-04
# Epoch 14/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.3972 - mae: 0.4493 - val_loss: 0.4810 - val_mae: 0.4391 - learning_rate: 5.0000e-04
# Epoch 15/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3838 - mae: 0.4376 - val_loss: 0.4710 - val_mae: 0.4271 - learning_rate: 5.0000e-04
# Epoch 16/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3830 - mae: 0.4386 - val_loss: 0.5301 - val_mae: 0.4967 - learning_rate: 5.0000e-04
# Epoch 17/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.3662 - mae: 0.4262 - val_loss: 0.5727 - val_mae: 0.5474 - learning_rate: 5.0000e-04
# Results - Train RMSE: 36.8793, Test RMSE: 36.3331, R2: -0.6743
#
# Combination 3/4: {'sequence_length': 24, 'lstm_units': [64], 'dropout_rate': 0.3, 'learning_rate': 0.001, 'batch_size': 64, 'epochs': 30}
# Progress: 75.0%
# Epoch 1/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.4822 - mae: 0.5074 - val_loss: 0.3086 - val_mae: 0.2841 - learning_rate: 0.0010
# Epoch 2/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3525 - mae: 0.4197 - val_loss: 0.3366 - val_mae: 0.3270 - learning_rate: 0.0010
# Epoch 3/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.3512 - mae: 0.4191 - val_loss: 0.3204 - val_mae: 0.2990 - learning_rate: 0.0010
# Epoch 4/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3557 - mae: 0.4232 - val_loss: 0.3188 - val_mae: 0.3088 - learning_rate: 0.0010
# Epoch 5/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.3302 - mae: 0.4052 - val_loss: 0.3146 - val_mae: 0.3101 - learning_rate: 0.0010
# Epoch 6/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3147 - mae: 0.3905 - val_loss: 0.3103 - val_mae: 0.3018 - learning_rate: 0.0010
# Epoch 7/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.2934 - mae: 0.3759 - val_loss: 0.3222 - val_mae: 0.3372 - learning_rate: 0.0010
# Epoch 8/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.2775 - mae: 0.3602 - val_loss: 0.2928 - val_mae: 0.2924 - learning_rate: 0.0010
# Epoch 9/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2389 - mae: 0.3308 - val_loss: 0.2642 - val_mae: 0.2573 - learning_rate: 0.0010
# Epoch 10/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2181 - mae: 0.3122 - val_loss: 0.2531 - val_mae: 0.2528 - learning_rate: 0.0010
# Epoch 11/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.2034 - mae: 0.2973 - val_loss: 0.2603 - val_mae: 0.2721 - learning_rate: 0.0010
# Epoch 12/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1957 - mae: 0.2938 - val_loss: 0.2464 - val_mae: 0.2586 - learning_rate: 0.0010
# Epoch 13/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1856 - mae: 0.2777 - val_loss: 0.2320 - val_mae: 0.2376 - learning_rate: 0.0010
# Epoch 14/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1731 - mae: 0.2617 - val_loss: 0.2748 - val_mae: 0.3144 - learning_rate: 0.0010
# Epoch 15/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1751 - mae: 0.2668 - val_loss: 0.2300 - val_mae: 0.2384 - learning_rate: 0.0010
# Epoch 16/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.1635 - mae: 0.2520 - val_loss: 0.2913 - val_mae: 0.3327 - learning_rate: 0.0010
# Epoch 17/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1680 - mae: 0.2548 - val_loss: 0.2620 - val_mae: 0.2979 - learning_rate: 0.0010
# Epoch 18/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1542 - mae: 0.2356 - val_loss: 0.2592 - val_mae: 0.2865 - learning_rate: 0.0010
# Epoch 19/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1481 - mae: 0.2293 - val_loss: 0.2243 - val_mae: 0.2193 - learning_rate: 0.0010
# Epoch 20/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1459 - mae: 0.2244 - val_loss: 0.2223 - val_mae: 0.2247 - learning_rate: 0.0010
# Epoch 21/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1438 - mae: 0.2246 - val_loss: 0.2255 - val_mae: 0.2300 - learning_rate: 0.0010
# Epoch 22/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1398 - mae: 0.2174 - val_loss: 0.2934 - val_mae: 0.3473 - learning_rate: 0.0010
# Epoch 23/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1409 - mae: 0.2215 - val_loss: 0.2288 - val_mae: 0.2393 - learning_rate: 0.0010
# Epoch 24/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1365 - mae: 0.2105 - val_loss: 0.2452 - val_mae: 0.2730 - learning_rate: 0.0010
# Epoch 25/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1327 - mae: 0.2091 - val_loss: 0.2503 - val_mae: 0.2715 - learning_rate: 0.0010
# Epoch 26/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1259 - mae: 0.1966 - val_loss: 0.2021 - val_mae: 0.1795 - learning_rate: 0.0010
# Epoch 27/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1213 - mae: 0.1903 - val_loss: 0.2156 - val_mae: 0.2128 - learning_rate: 0.0010
# Epoch 28/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.1264 - mae: 0.2005 - val_loss: 0.1960 - val_mae: 0.1592 - learning_rate: 0.0010
# Epoch 29/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1253 - mae: 0.1950 - val_loss: 0.2269 - val_mae: 0.2481 - learning_rate: 0.0010
# Epoch 30/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1272 - mae: 0.2002 - val_loss: 0.2389 - val_mae: 0.2700 - learning_rate: 0.0010
# Results - Train RMSE: 20.5661, Test RMSE: 25.0889, R2: 0.2017
# New best model found!
#
# Combination 4/4: {'sequence_length': 24, 'lstm_units': [64], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'batch_size': 64, 'epochs': 30}
# Progress: 100.0%
# Epoch 1/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.7507 - mae: 0.6528 - val_loss: 0.3341 - val_mae: 0.3017 - learning_rate: 0.0010
# Epoch 2/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.4453 - mae: 0.4875 - val_loss: 0.3520 - val_mae: 0.3442 - learning_rate: 0.0010
# Epoch 3/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4320 - mae: 0.4762 - val_loss: 0.3163 - val_mae: 0.3011 - learning_rate: 0.0010
# Epoch 4/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.3934 - mae: 0.4560 - val_loss: 0.3373 - val_mae: 0.3316 - learning_rate: 0.0010
# Epoch 5/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3848 - mae: 0.4473 - val_loss: 0.3032 - val_mae: 0.2800 - learning_rate: 0.0010
# Epoch 6/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3833 - mae: 0.4418 - val_loss: 0.2838 - val_mae: 0.2613 - learning_rate: 0.0010
# Epoch 7/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3583 - mae: 0.4257 - val_loss: 0.3011 - val_mae: 0.2936 - learning_rate: 0.0010
# Epoch 8/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.3516 - mae: 0.4193 - val_loss: 0.2970 - val_mae: 0.2917 - learning_rate: 0.0010
# Epoch 9/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.3360 - mae: 0.4098 - val_loss: 0.2743 - val_mae: 0.2551 - learning_rate: 0.0010
# Epoch 10/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.3210 - mae: 0.3892 - val_loss: 0.2953 - val_mae: 0.2868 - learning_rate: 0.0010
# Epoch 11/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.3352 - mae: 0.4026 - val_loss: 0.3293 - val_mae: 0.3378 - learning_rate: 0.0010
# Epoch 12/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3362 - mae: 0.4029 - val_loss: 0.2781 - val_mae: 0.2555 - learning_rate: 0.0010
# Epoch 13/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.3242 - mae: 0.3880 - val_loss: 0.2774 - val_mae: 0.2608 - learning_rate: 0.0010
# Epoch 14/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.3115 - mae: 0.3789 - val_loss: 0.2904 - val_mae: 0.2893 - learning_rate: 0.0010
# Epoch 15/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3075 - mae: 0.3739 - val_loss: 0.3049 - val_mae: 0.3115 - learning_rate: 0.0010
# Epoch 16/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.2903 - mae: 0.3633 - val_loss: 0.2658 - val_mae: 0.2636 - learning_rate: 0.0010
# Epoch 17/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3032 - mae: 0.3632 - val_loss: 0.3292 - val_mae: 0.3585 - learning_rate: 0.0010
# Epoch 18/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2778 - mae: 0.3479 - val_loss: 0.2776 - val_mae: 0.2836 - learning_rate: 0.0010
# Epoch 19/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.2523 - mae: 0.3248 - val_loss: 0.2902 - val_mae: 0.2961 - learning_rate: 0.0010
# Epoch 20/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2411 - mae: 0.3159 - val_loss: 0.2915 - val_mae: 0.3020 - learning_rate: 0.0010
# Epoch 21/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.2322 - mae: 0.3016 - val_loss: 0.3224 - val_mae: 0.3448 - learning_rate: 0.0010
# Epoch 22/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2407 - mae: 0.3138 - val_loss: 0.3248 - val_mae: 0.3597 - learning_rate: 0.0010
# Epoch 23/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.2113 - mae: 0.2823 - val_loss: 0.2986 - val_mae: 0.3230 - learning_rate: 0.0010
# Epoch 24/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2126 - mae: 0.2825 - val_loss: 0.4928 - val_mae: 0.5441 - learning_rate: 0.0010
# Epoch 25/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.1975 - mae: 0.2698 - val_loss: 0.3597 - val_mae: 0.4059 - learning_rate: 5.0000e-04
# Epoch 26/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1780 - mae: 0.2506 - val_loss: 0.2912 - val_mae: 0.3263 - learning_rate: 5.0000e-04
# Epoch 27/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.1745 - mae: 0.2494 - val_loss: 0.3181 - val_mae: 0.3618 - learning_rate: 5.0000e-04
# Epoch 28/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1706 - mae: 0.2419 - val_loss: 0.3387 - val_mae: 0.3852 - learning_rate: 5.0000e-04
# Epoch 29/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1601 - mae: 0.2381 - val_loss: 0.3518 - val_mae: 0.3913 - learning_rate: 5.0000e-04
# Epoch 30/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1639 - mae: 0.2316 - val_loss: 0.3373 - val_mae: 0.3861 - learning_rate: 5.0000e-04
# Results - Train RMSE: 27.1878, Test RMSE: 28.5874, R2: -0.0365
#
# Grid search completed. Best RMSE: 25.0889
# Best parameters: {'sequence_length': 24, 'lstm_units': [64], 'dropout_rate': 0.3, 'learning_rate': 0.001, 'batch_size': 64, 'epochs': 30}

# %%
results_df = pd.DataFrame([r for r in results if 'error' not in r])
results_df.to_csv('lstm_brobust_grid_search_results.csv', index=False)
print(f"Results saved to lstm_grid_search_results.csv")
# Out:
# Results saved to lstm_grid_search_results.csv

# %%
# Create sequences with best parameters
SEQUENCE_LENGTH = best_params['sequence_length']
X_seq_final, y_seq_final = create_sequences(X_train, y_train_scaled, SEQUENCE_LENGTH)

# %%
# Build final model with best parameters
final_model = build_model(
    best_params['sequence_length'],
    X_seq_final.shape[2],
    best_params['lstm_units'],
    best_params['dropout_rate'],
    best_params['learning_rate']
)

# %%
# Train on ALL training data (no validation split for final model)
callbacks = [
    EarlyStopping(monitor='loss', patience=20, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, min_lr=0.00001, verbose=1)
]

# %%
final_history = final_model.fit(
    X_seq_final, y_seq_final,
    epochs=best_params['epochs'] + 20,  # Allow more epochs for final training
    batch_size=best_params['batch_size'],
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-24-1935678007.py in <cell line: 0>()
# ----> 1 final_history = final_model.fit(
#       2     X_seq_final, y_seq_final,
#       3     epochs=best_params['epochs'] + 20,  # Allow more epochs for final training
#       4     batch_size=best_params['batch_size'],
#       5     callbacks=callbacks,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     917           )
#     918       )
# --> 919       return self._concrete_variable_creation_fn._call_flat(  # pylint: disable=protected-access
#     920           filtered_flat_args,
#     921           self._concrete_variable_creation_fn.captured_inputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Training evaluation (convert scaled targets back to original scale)
y_train_actual = scaler_y.inverse_transform(y_seq_final.reshape(-1, 1)).flatten()
final_train_metrics = evaluate_model(final_model, X_seq_final, y_train_actual, scaler_y)

# Test evaluation
X_test_seq, _ = create_sequences(X_test, y_test.flatten(), SEQUENCE_LENGTH)
y_test_actual = y_test[SEQUENCE_LENGTH:]
final_test_metrics = evaluate_model(final_model, X_test_seq, y_test_actual, scaler_y)

print(f"\nFinal Model Performance:")
print(f"TRAINING SET:")
print(f"  Train RMSE: {final_train_metrics['rmse']:.4f}")
print(f"  Train R2: {final_train_metrics['r2']:.4f}")
print(f"  Train MAE: {final_train_metrics['mae']:.4f}")
print(f"  Train MAPE: {final_train_metrics['mape']:.4f}")

print(f"\nTEST SET:")
print(f"  Test RMSE: {final_test_metrics['rmse']:.4f}")
print(f"  Test R2: {final_test_metrics['r2']:.4f}")
print(f"  Test MAE: {final_test_metrics['mae']:.4f}")
print(f"  Test MAPE: {final_test_metrics['mape']:.4f}")

print(f"\nOVERFITTING ANALYSIS:")
print(f"  RMSE Difference (Train - Test): {final_train_metrics['rmse'] - final_test_metrics['rmse']:.4f}")
print(f"  R2 Difference (Train - Test): {final_train_metrics['r2'] - final_test_metrics['r2']:.4f}")
print(f"  MAE Difference (Train - Test): {final_train_metrics['mae'] - final_test_metrics['mae']:.4f}")
print(f"  MAPE Difference (Train - Test): {final_train_metrics['mape'] - final_test_metrics['mape']:.4f}")

# Save final model
final_model.save('best_lstm_model.h5')
print("\nFinal model saved as 'best_lstm_model.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Final Model Performance:
# TRAINING SET:
#   Train RMSE: 44.6697
#   Train R2: 0.0311
#   Train MAE: 41.7557
#   Train MAPE: 7.5235
#
# TEST SET:
#   Test RMSE: 52.4711
#   Test R2: -2.4919
#   Test MAE: 48.3058
#   Test MAPE: 8.5214
#
# OVERFITTING ANALYSIS:
#   RMSE Difference (Train - Test): -7.8014
#   R2 Difference (Train - Test): 2.5230
#   MAE Difference (Train - Test): -6.5501
#   MAPE Difference (Train - Test): -0.9979
#
# Final model saved as 'best_lstm_model.h5'
